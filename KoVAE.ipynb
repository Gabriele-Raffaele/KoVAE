# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriele-Raffaele/KoVAE/blob/main/KoVAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone "https://github.com/Gabriele-Raffaele/KoVAE.git"
# Out:
# Cloning into 'KoVAE'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 189 (delta 15), reused 23 (delta 12), pack-reused 154 (from 1)
# Receiving objects: 100% (189/189), 3.07 MiB | 18.69 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
pip_requirements = """
absl-py==1.4.0
argparse==1.4.0
arrow==1.2.3
astunparse==1.6.3
attrs==23.1.0
boto3==1.26.149
botocore==1.29.149
bravado==11.0.3
bravado-core==5.17.1
cachetools==5.3.0
certifi==2022.12.7
click==8.1.3
contourpy==1.0.7
cycler==0.11.0
flatbuffers==23.3.3
fonttools==4.39.3
fqdn==1.5.1
gast==0.4.0
gitdb==4.0.10
gitpython==3.1.31
google-auth==2.17.3
google-auth-oauthlib==1.0.0
google-pasta==0.2.0
grpcio==1.53.0
h5py==3.8.0
importlib-metadata==6.4.1
importlib-resources==5.12.0
isoduration==20.11.0
jax==0.4.8
jmespath==1.0.1
joblib==1.2.0
jsonpointer==2.3
jsonref==1.1.0
jsonschema==4.17.3
keras==2.12.0
kiwisolver==1.4.4
libclang==16.0.0
markdown==3.4.3
matplotlib==3.7.1
ml-dtypes==0.1.0
monotonic==1.6
msgpack==1.0.5
neptune==1.2.0
nvidia-cublas-cu11==11.11.3.6
nvidia-cudnn-cu11==8.6.0.163
oauthlib==3.2.2
opt-einsum==3.3.0
packaging==23.1
pandas==2.0.2
pillow==9.5.0
protobuf==4.22.3
psutil==5.9.5
pyasn1==0.4.8
pyasn1-modules==0.2.8
pyjwt==2.7.0
pyparsing==3.0.9
pyrsistent==0.19.3
python-dateutil==2.8.2
pytz==2023.3
pyyaml==6.0
requests-oauthlib==1.3.1
rfc3339-validator==0.1.4
rfc3987==1.3.8
rsa==4.9
s3transfer==0.6.1
scikit-learn==1.2.2
scipy==1.10.1
simplejson==3.19.1
smmap==5.0.0
swagger-spec-validator==3.0.3
tensorboard==2.12.2
tensorboard-data-server==0.7.0
tensorboard-plugin-wit==1.8.1
tensorflow==2.12.0
tensorflow-estimator==2.12.0
tensorflow-io-gcs-filesystem==0.32.0
termcolor==2.2.0
threadpoolctl==3.1.0
torchdiffeq==0.2.3
tzdata==2023.3
uri-template==1.2.0
webcolors==1.13
websocket-client==1.5.2
werkzeug==2.2.3
wrapt==1.14.1
zipp==3.15.0
"""
with open("requirements.txt", "w") as f:
    f.write(pip_requirements)

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 96.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# %rm -r KoVAE/

# %%
# %cd KoVAE/
# Out:
# /content/KoVAE

# %%
# !pip install jax==0.4.7 jaxlib==0.4.7
# Out:
# ...
#   Using cached jax-0.4.7.tar.gz (1.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 MB 16.2 MB/s eta 0:00:00
# ...
#   Created wheel for jax: filename=jax-0.4.7-py3-none-any.whl size=1438270 sha256=ebabae8da66286ac87a0b55b09cbc9ca7c9c13e6b82c61a310aa87f6be9c8d33
#   Stored in directory: /root/.cache/pip/wheels/d9/71/c5/be5b21636723e8726709ea3c997622471c109387271c61827e
# Successfully built jax
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.5.1
#     Uninstalling jaxlib-0.5.1:
#       Successfully uninstalled jaxlib-0.5.1
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.8
#     Uninstalling jax-0.4.8:
#       Successfully uninstalled jax-0.4.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python3 run_irregular.py --dataset dumarey --epoch 10 --inp_dim 12 --w_kl .009 --w_pred_prior .03
# Out:
# 2025-05-25 18:19:51.354349: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-25 18:19:51.450798: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-25 18:19:52.842696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/KoVAE/run_irregular.py:5: NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.
#   import neptune.new as neptune
# cuda is available
# 2025-05-25 18:19:55,191 - INFO - dumarey dataset is ready.
# ...

# %%
# %cd ../..
# Out:
# /content/KoVAE

# %%
# %ls
